# %% [markdown]
# <a href="https://colab.research.google.com/github/Lecastrot/MetNumUN2023I/blob/main/lecastrot_Lab3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ![image_2023-03-05_195001169.png](data:image/png;base64,...)

# %% [markdown]
# ![image_2023-03-05_195052445.png](data:image/png;base64,...)

# %% [markdown]
# ![image_2023-03-05_195123484.png](data:image/png;base64,...)

# %% [markdown]
# https://www.linkedin.com/in/leonardo-castro-torres-35b36a203/
